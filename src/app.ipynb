# %% [markdown]
# # Simulação de aplicação
#
# O paradigma SSVEP é bastante utilizado em aplicações reais por ser fácil de evocar os sinais e posteriormente classificá-los.
#
# Para processar uma aplicação SSVEP em tempo real é necessário calcular a máxima energia dos _targets_ em janelas ou _buffers_ suficientemente grandes. O tamanho da janela de dados é inversamente proporcional a taxa de amostragem do equipamente de EEG utilizado. Ou seja, quanto maior a taxa de amostragem, menor o tempo decessário para calcular a **energia deslizante do sinal**
#
# **Tarefa**: simule uma aplicação SSVEP criando um buffer do sinal no domínio do tempo em uma única dimensão. Se inicialmente a dimensão dos dados era `(100, 8192)`, agora será `(819200)`. Crie um buffer de 3 ou 4 segundos, informando a cada segundo qual está sendo a frequência evocada.

# %%
import numpy as np
import mne
from scipy.signal import welch
import json

# Carregar os dados no domínio do tempo
epochs = mne.read_epochs('ssvep-epo.fif')
data = epochs.get_data().squeeze().flatten()  # shape de (100, 1, 8192) -> (100, 8192) -> (819200,)

# Parâmetros do buffer
sampling_rate = 512  # Taxa de amostragem do EEG (Hz)
buffer_size = 4  # Tamanho do buffer em segundos
step_size = 1  # Tamanho do passo do buffer em segundos

buffer_samples = buffer_size * sampling_rate  # Tamanho do buffer em amostras
step_samples = step_size * sampling_rate  # Passo do buffer em amostras

# Frequências esperadas (para simulação)
frequencies = [6.0, 6.5, 7.0, 7.5, 8.2, 9.3]

# Resultados finais para exportação
results = []

# Janela para média móvel (em buffers)
moving_average_window = 3
recent_predictions = []

# Simulação do buffer
print("Simulação de aplicação SSVEP:")
for start in range(0, len(data) - buffer_samples, step_samples):  # Avançar 1 segundo
    # Extrair o segmento do buffer
    buffer = data[start : start + buffer_samples]
    
    # Calcular a PSD do buffer usando Welch
    freqs, psd = welch(buffer, fs=sampling_rate, nperseg=buffer_samples)
    
    # Encontrar a frequência com maior energia
    max_idx = np.argmax(psd)
    predicted_freq = freqs[max_idx]
    
    # Comparar com as frequências esperadas usando tolerância de ±0.5 Hz
    closest_freq = min(frequencies, key=lambda x: abs(x - predicted_freq))
    within_tolerance = abs(predicted_freq - closest_freq) <= 0.5
    
    # Adicionar à janela de média móvel
    recent_predictions.append(closest_freq if within_tolerance else None)
    if len(recent_predictions) > moving_average_window:
        recent_predictions.pop(0)
    
    # Calcular a frequência dominante (média móvel simples)
    valid_predictions = [p for p in recent_predictions if p is not None]
    dominant_freq = np.mean(valid_predictions) if valid_predictions else None
    
    # Exibir os resultados
    print(f"Buffer {start // step_samples + 1}:")
    print(f"  Frequência evocada estimada: {predicted_freq:.2f} Hz")
    print(f"  Frequência mais próxima dos alvos: {closest_freq:.2f} Hz")
    print(f"  Frequência dominante (média móvel): {dominant_freq:.2f} Hz\n" if dominant_freq else "  Sem frequência dominante detectada\n")
    
    # Armazenar o resultado
    results.append({
        "buffer_number": start // step_samples + 1,
        "predicted_frequency": predicted_freq,
        "closest_target_frequency": closest_freq,
        "within_tolerance": within_tolerance,
        "dominant_frequency": dominant_freq
    })

# Exportar os resultados para um arquivo JSON
with open("ssvep_results.json", "w") as f:
    json.dump(results, f, indent=4, default=str)
# Out:
# Reading c:\Users\catar\Downloads\multi\multi\src\ssvep-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...   15998.05 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# Simulação de aplicação SSVEP:
# Buffer 1:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 2:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 3:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 4:
#   Frequência evocada estimada: 7.75 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 5:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 6:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 7:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.10 Hz
#
# Buffer 8:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 7.60 Hz
#
# Buffer 9:
#   Frequência evocada estimada: 7.25 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.43 Hz
#
# Buffer 10:
#   Frequência evocada estimada: 7.25 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.67 Hz
#
# Buffer 11:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.67 Hz
#
# Buffer 12:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.33 Hz
#
# Buffer 13:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 14:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 15:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 16:
#   Frequência evocada estimada: 5.50 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 17:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 18:
#   Frequência evocada estimada: 18.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 19:
#   Frequência evocada estimada: 11.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 20:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 21:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 22:
#   Frequência evocada estimada: 11.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 23:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 24:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 25:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 26:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 27:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 28:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 29:
#   Frequência evocada estimada: 9.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 30:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 31:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 32:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 33:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.25 Hz
#
# Buffer 34:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.17 Hz
#
# Buffer 35:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 36:
#   Frequência evocada estimada: 8.50 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.60 Hz
#
# Buffer 37:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 38:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 39:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 40:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 41:
#   Frequência evocada estimada: 11.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 42:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 43:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 44:
#   Frequência evocada estimada: 17.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 45:
#   Frequência evocada estimada: 17.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 46:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 47:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 48:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.40 Hz
#
# Buffer 49:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.80 Hz
#
# Buffer 50:
#   Frequência evocada estimada: 11.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 51:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 52:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 53:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 6.73 Hz
#
# Buffer 54:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.83 Hz
#
# Buffer 55:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.75 Hz
#
# Buffer 56:
#   Frequência evocada estimada: 15.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 57:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 58:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 59:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 60:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 61:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 62:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 63:
#   Frequência evocada estimada: 17.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 64:
#   Frequência evocada estimada: 17.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 65:
#   Frequência evocada estimada: 17.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 66:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 67:
#   Frequência evocada estimada: 18.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 68:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 69:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 70:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 71:
#   Frequência evocada estimada: 10.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 72:
#   Frequência evocada estimada: 7.75 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 73:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 74:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 75:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 76:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 77:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 78:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 79:
#   Frequência evocada estimada: 11.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 80:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 81:
#   Frequência evocada estimada: 15.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 82:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 83:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 84:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 85:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 86:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 87:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 88:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 89:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 90:
#   Frequência evocada estimada: 16.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 91:
#   Frequência evocada estimada: 13.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 92:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 93:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 94:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 95:
#   Frequência evocada estimada: 15.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 96:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 97:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 98:
#   Frequência evocada estimada: 19.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 99:
#   Frequência evocada estimada: 11.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 100:
#   Frequência evocada estimada: 11.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 101:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 102:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 103:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 104:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 105:
#   Frequência evocada estimada: 9.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 106:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.65 Hz
#
# Buffer 107:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 108:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 109:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 110:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 111:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 112:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 113:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 114:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.33 Hz
#
# Buffer 115:
#   Frequência evocada estimada: 11.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 116:
#   Frequência evocada estimada: 11.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 117:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 118:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 119:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 120:
#   Frequência evocada estimada: 16.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 121:
#   Frequência evocada estimada: 16.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 122:
#   Frequência evocada estimada: 9.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 123:
#   Frequência evocada estimada: 11.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 124:
#   Frequência evocada estimada: 9.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 125:
#   Frequência evocada estimada: 9.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 126:
#   Frequência evocada estimada: 19.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 127:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 7.90 Hz
#
# Buffer 128:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 129:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 130:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 131:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 132:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 133:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 134:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 135:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 136:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 137:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 138:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 139:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 140:
#   Frequência evocada estimada: 15.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 141:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 142:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 143:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 144:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.33 Hz
#
# Buffer 145:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 146:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 147:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 148:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 149:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 150:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 151:
#   Frequência evocada estimada: 10.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 152:
#   Frequência evocada estimada: 10.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 153:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 154:
#   Frequência evocada estimada: 14.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 155:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 156:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 157:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 158:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 159:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 160:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 161:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.75 Hz
#
# Buffer 162:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 7.83 Hz
#
# Buffer 163:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 164:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 165:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 166:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 167:
#   Frequência evocada estimada: 10.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 168:
#   Frequência evocada estimada: 10.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 169:
#   Frequência evocada estimada: 17.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 170:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 171:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 172:
#   Frequência evocada estimada: 18.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 173:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.40 Hz
#
# Buffer 174:
#   Frequência evocada estimada: 9.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 175:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 176:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 177:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 178:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 179:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 180:
#   Frequência evocada estimada: 17.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 181:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 182:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 183:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 184:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 185:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 186:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 187:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 188:
#   Frequência evocada estimada: 16.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 189:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 190:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 191:
#   Frequência evocada estimada: 5.50 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 192:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 193:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 194:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 195:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 196:
#   Frequência evocada estimada: 17.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 197:
#   Frequência evocada estimada: 18.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 198:
#   Frequência evocada estimada: 18.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 199:
#   Frequência evocada estimada: 19.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 200:
#   Frequência evocada estimada: 13.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 201:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 202:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 203:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 204:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 205:
#   Frequência evocada estimada: 16.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 206:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 207:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 208:
#   Frequência evocada estimada: 21.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 209:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 210:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 211:
#   Frequência evocada estimada: 17.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 212:
#   Frequência evocada estimada: 19.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 213:
#   Frequência evocada estimada: 19.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 214:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 215:
#   Frequência evocada estimada: 9.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 216:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 217:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 218:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 219:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 220:
#   Frequência evocada estimada: 17.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 221:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 222:
#   Frequência evocada estimada: 10.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 223:
#   Frequência evocada estimada: 10.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 224:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 225:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 226:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 227:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 228:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 229:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 230:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 231:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 232:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 233:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 234:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.33 Hz
#
# Buffer 235:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 236:
#   Frequência evocada estimada: 13.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 237:
#   Frequência evocada estimada: 13.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 238:
#   Frequência evocada estimada: 8.75 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Sem frequência dominante detectada
#
# Buffer 239:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 240:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 241:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.33 Hz
#
# Buffer 242:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.07 Hz
#
# Buffer 243:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.35 Hz
#
# Buffer 244:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 245:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 246:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 247:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 248:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 249:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 250:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 251:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 252:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 253:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 254:
#   Frequência evocada estimada: 9.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.65 Hz
#
# Buffer 255:
#   Frequência evocada estimada: 9.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 256:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 257:
#   Frequência evocada estimada: 11.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 258:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 259:
#   Frequência evocada estimada: 10.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 260:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 261:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 262:
#   Frequência evocada estimada: 12.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 263:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 264:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 265:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 266:
#   Frequência evocada estimada: 9.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 267:
#   Frequência evocada estimada: 9.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 268:
#   Frequência evocada estimada: 14.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 269:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 7.90 Hz
#
# Buffer 270:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 271:
#   Frequência evocada estimada: 13.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 272:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 273:
#   Frequência evocada estimada: 12.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 274:
#   Frequência evocada estimada: 19.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 275:
#   Frequência evocada estimada: 19.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 276:
#   Frequência evocada estimada: 15.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 277:
#   Frequência evocada estimada: 14.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 278:
#   Frequência evocada estimada: 14.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 279:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 280:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 281:
#   Frequência evocada estimada: 17.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 282:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 283:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 284:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 285:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 286:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 287:
#   Frequência evocada estimada: 18.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 288:
#   Frequência evocada estimada: 14.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 289:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 290:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 291:
#   Frequência evocada estimada: 19.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 292:
#   Frequência evocada estimada: 19.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 293:
#   Frequência evocada estimada: 11.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 294:
#   Frequência evocada estimada: 12.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 295:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 296:
#   Frequência evocada estimada: 14.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 297:
#   Frequência evocada estimada: 14.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 298:
#   Frequência evocada estimada: 9.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 299:
#   Frequência evocada estimada: 10.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 300:
#   Frequência evocada estimada: 14.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 301:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 302:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 303:
#   Frequência evocada estimada: 5.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 304:
#   Frequência evocada estimada: 4.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 305:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 306:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 307:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 308:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 309:
#   Frequência evocada estimada: 21.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 310:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 311:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 312:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 313:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 314:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 315:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 316:
#   Frequência evocada estimada: 18.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 317:
#   Frequência evocada estimada: 15.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 318:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 319:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 320:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 6.73 Hz
#
# Buffer 321:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.47 Hz
#
# Buffer 322:
#   Frequência evocada estimada: 7.75 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.97 Hz
#
# Buffer 323:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.73 Hz
#
# Buffer 324:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 325:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 326:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 327:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 328:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 329:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 330:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 331:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 332:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 333:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 334:
#   Frequência evocada estimada: 7.75 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 335:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.73 Hz
#
# Buffer 336:
#   Frequência evocada estimada: 8.00 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 7.97 Hz
#
# Buffer 337:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 338:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 339:
#   Frequência evocada estimada: 8.25 Hz
# ...
#
# Buffer 1485:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1486:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1487:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1488:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 1489:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1490:
#   Frequência evocada estimada: 5.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 1491:
#   Frequência evocada estimada: 16.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1492:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1493:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 1494:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.75 Hz
#
# Buffer 1495:
#   Frequência evocada estimada: 10.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.75 Hz
#
# Buffer 1496:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.75 Hz
#
# Buffer 1497:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 7.10 Hz
#
# Buffer 1498:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.73 Hz
#
# Buffer 1499:
#   Frequência evocada estimada: 10.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1500:
#   Frequência evocada estimada: 16.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1501:
#   Frequência evocada estimada: 9.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 1502:
#   Frequência evocada estimada: 9.25 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 1503:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 8.37 Hz
#
# Buffer 1504:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.77 Hz
#
# Buffer 1505:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1506:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1507:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1508:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1509:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1510:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1511:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1512:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1513:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1514:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1515:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1516:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1517:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1518:
#   Frequência evocada estimada: 4.50 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1519:
#   Frequência evocada estimada: 5.50 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1520:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1521:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1522:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1523:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1524:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1525:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1526:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1527:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1528:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1529:
#   Frequência evocada estimada: 5.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1530:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 1531:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1532:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1533:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1534:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1535:
#   Frequência evocada estimada: 7.75 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 6.67 Hz
#
# Buffer 1536:
#   Frequência evocada estimada: 10.50 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 1537:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1538:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1539:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1540:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1541:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1542:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1543:
#   Frequência evocada estimada: 9.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 1544:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 1545:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 9.30 Hz
#
# Buffer 1546:
#   Frequência evocada estimada: 15.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1547:
#   Frequência evocada estimada: 10.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1548:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1549:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1550:
#   Frequência evocada estimada: 4.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1551:
#   Frequência evocada estimada: 7.50 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 1552:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1553:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 1554:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1555:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.17 Hz
#
# Buffer 1556:
#   Frequência evocada estimada: 13.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1557:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1558:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1559:
#   Frequência evocada estimada: 8.25 Hz
#   Frequência mais próxima dos alvos: 8.20 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 1560:
#   Frequência evocada estimada: 13.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 1561:
#   Frequência evocada estimada: 5.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 8.20 Hz
#
# Buffer 1562:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1563:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1564:
#   Frequência evocada estimada: 14.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1565:
#   Frequência evocada estimada: 6.75 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1566:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1567:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1568:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1569:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1570:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1571:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1572:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1573:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1574:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1575:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1576:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.00 Hz
#
# Buffer 1577:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1578:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1579:
#   Frequência evocada estimada: 5.50 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1580:
#   Frequência evocada estimada: 5.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1581:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1582:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1583:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1584:
#   Frequência evocada estimada: 10.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1585:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1586:
#   Frequência evocada estimada: 5.75 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1587:
#   Frequência evocada estimada: 6.00 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1588:
#   Frequência evocada estimada: 7.75 Hz
#   Frequência mais próxima dos alvos: 7.50 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1589:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.75 Hz
#
# Buffer 1590:
#   Frequência evocada estimada: 11.75 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 7.50 Hz
#
# Buffer 1591:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1592:
#   Frequência evocada estimada: 10.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Sem frequência dominante detectada
#
# Buffer 1593:
#   Frequência evocada estimada: 6.25 Hz
#   Frequência mais próxima dos alvos: 6.00 Hz
#   Frequência dominante (média móvel): 6.00 Hz
#
# Buffer 1594:
#   Frequência evocada estimada: 6.50 Hz
#   Frequência mais próxima dos alvos: 6.50 Hz
#   Frequência dominante (média móvel): 6.25 Hz
#
# Buffer 1595:
#   Frequência evocada estimada: 7.00 Hz
#   Frequência mais próxima dos alvos: 7.00 Hz
#   Frequência dominante (média móvel): 6.50 Hz
#
# Buffer 1596:
#   Frequência evocada estimada: 12.00 Hz
#   Frequência mais próxima dos alvos: 9.30 Hz
#   Frequência dominante (média móvel): 6.75 Hz
